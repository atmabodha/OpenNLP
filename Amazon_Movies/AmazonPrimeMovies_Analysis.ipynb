# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Amazon_Prime_Movies.xlsx")
df
# Out:
#                          title    year  imdb_rating maturity_rating  \
# 0                       Thrash  2026.0          5.0             NaN
# 1             Wake Up Dead Man  2025.0          7.3             NaN
# 2                     Superman  2025.0          7.0             NaN
# 3                F1: The Movie  2025.0          7.6             NaN
# 4     One Battle After Another  2025.0          7.7             NaN
# ...                        ...     ...          ...             ...
# 7253                    Page 3  2005.0          NaN             16+
# 7254          Secretary (2002)  2002.0          NaN             18+
# 7255                Veer Zaara  2004.0          NaN              7+
# 7256                    Loafer  1973.0          NaN             All
# 7257       Khandani Shafakhana  2019.0          NaN             13+
#
#          imdb_id                                       plot_summary  \
# 0     tt32362890  The town of Annieville, South Carolina awaits ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7258 entries, 0 to 7257
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 7258 non-null   object
#  1   year                  7140 non-null   float64
#  2   imdb_rating           5982 non-null   float64
#  3   maturity_rating       1276 non-null   object
#  4   imdb_id               5982 non-null   object
#  5   plot_summary          7258 non-null   object
#  6   cast                  5951 non-null   object
#  7   critical_response     5635 non-null   object
#  8   running_time          7239 non-null   object
#  9   Directed by           7252 non-null   object
#  10  Written by            4237 non-null   object
#  11  Starring              7205 non-null   object
#  12  Cinematography        6877 non-null   object
#  13  Edited by             7042 non-null   object
#  14  Music by              7069 non-null   object
# ...
